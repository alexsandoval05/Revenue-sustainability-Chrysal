# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


df = pd.read_csv("/content/Chrysal_Marketing_Sales_Sustainability_Portfolio_Dataset_v3.csv")

# %%
df.head()
# Out:
#    Year    Month   Country Product_Reference     Category  \
# 0  2024  Febrero   Holanda    Chrysal Grow X    Fungicida
# 1  2025    Enero     Kenya   Chrysal Flora F  Nutricional
# 2  2022     Mayo   Ecuador   Chrysal Flora F  Insecticida
# 3  2024     Mayo     Kenya   Chrysal Flora F  Nutricional
# 4  2024    Abril  Colombia    Chrysal Grow X  Insecticida
#
#   Marketing_Campaign_Type  Sales_Units  Marketing_Investment_USD  \
# 0            Social Media        20893                    6751.0
# 1   Influencers Agrícolas         6955                       NaN
# 2            Social Media        34287                       NaN
# 3   Influencers Agrícolas        21763                    6751.0
# 4          Field Campaign        21736                    6751.0
#
#    Sales_Revenue_USD  Production_Cost_USD  Gross_Margin_USD  Marketing_ROI  \
# 0          127316.56             57858.21          69458.35          18.86
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      700 non-null    int64
#  1   Month                     700 non-null    object
#  2   Country                   700 non-null    object
#  3   Product_Reference         700 non-null    object
#  4   Category                  700 non-null    object
#  5   Marketing_Campaign_Type   700 non-null    object
#  6   Sales_Units               700 non-null    int64
#  7   Marketing_Investment_USD  346 non-null    float64
#  8   Sales_Revenue_USD         630 non-null    float64
#  9   Production_Cost_USD       700 non-null    float64
#  10  Gross_Margin_USD          700 non-null    float64
#  11  Marketing_ROI             346 non-null    float64
#  12  Waste_Generated_kg        665 non-null    float64
# dtypes: float64(6), int64(2), object(5)
# ...

# %%
df.describe()
# Out:
#               Year   Sales_Units  Marketing_Investment_USD  Sales_Revenue_USD  \
# count   700.000000    700.000000                     346.0         630.000000
# mean   2023.560000  18357.522857                    6751.0       94651.089063
# std       1.136267   9812.482659                       0.0       51459.167383
# min    2022.000000    882.000000                    6751.0        4838.780000
# 25%    2023.000000  10406.500000                    6751.0       52970.632500
# 50%    2024.000000  19521.000000                    6751.0       95928.995000
# 75%    2025.000000  26854.000000                    6751.0      134256.020000
# max    2025.000000  34948.000000                    6751.0      222096.760000
#
#        Production_Cost_USD  Gross_Margin_USD  Marketing_ROI  \
# count           700.000000        700.000000     346.000000
# mean          51202.551386      42214.134186      13.423584
# std           29005.844290      24410.604150       7.666074
# ...

# %%
ventas_pais = df.copy()

# %%
ventas_paises = ventas_pais[(ventas_pais['Country']=='Colombia') |
(ventas_pais['Country']=='Ecuador')]
ventas_paises
# Out:
#      Year    Month   Country Product_Reference                  Category  \
# 2    2022     Mayo   Ecuador   Chrysal Flora F               Insecticida
# 4    2024    Abril  Colombia    Chrysal Grow X               Insecticida
# 5    2025  Febrero  Colombia    Chrysal Grow X               Insecticida
# 6    2022    Enero   Ecuador   Chrysal Flora F               Nutricional
# 8    2024    Marzo   Ecuador    Chrysal Root R               Insecticida
# ..    ...      ...       ...               ...                       ...
# 692  2022     Mayo  Colombia    Chrysal Grow X  Regulador de crecimiento
# 695  2025  Febrero  Colombia   Chrysal Boost Z              Fertilizante
# 697  2023     Mayo   Ecuador    Chrysal Root R               Nutricional
# 698  2023    Marzo  Colombia   Chrysal Flora F               Insecticida
# 699  2024     Mayo  Colombia    Chrysal Root R               Insecticida
#
#     Marketing_Campaign_Type  Sales_Units  Marketing_Investment_USD  \
# ...

# %%
ventas_paises['Sales_Revenue_USD'].hist(bins=10, figsize=(10, 5)) # figsize=(ancho, alto)
plt.title('Revenue _USD')
plt.xlabel('USD')
plt.ylabel('Frecuency (Number of registers)')
plt.show()

# %%
ventas_pais.groupby("Country")["Sales_Revenue_USD"].mean().reset_index().sort_values(by="Sales_Revenue_USD")
# Out:
#     Country  Sales_Revenue_USD
# 2   Holanda       93438.857421
# 1   Ecuador       93790.497600
# 3     Kenya       94683.535442
# 0  Colombia       96923.429463
